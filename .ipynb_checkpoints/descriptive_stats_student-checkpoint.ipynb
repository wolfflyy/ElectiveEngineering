# %% [markdown]
# # Statistics

# %% [markdown]
# 1. Two forms of Statistics
# 2. Common descriptive statistical measures (central tendency, dispersion and correlation)

# %% [markdown]
# ## 1. Two Forms of Statistics

# %% [markdown]
# **What is Statistics?**
# - A set of methods and measures that deal with collecting, cleaning and analyzing a dataset
# - making quantitative statements about the population
#
#
# - **1-descriptive statistics**
# - **2-inferential statistics**:
#
#   * Descriptive statistics describes data (e.g. calculating the average age of the students in our class)
#
#   * Inferential statistics about predictions. It uses statistical models to help you compare your sample data to other samples or to previous research

# %% [markdown]
# ### What is a population ? What is a sample ?

# %% [markdown]
# <div>
# <img src="attachment:population.png" width="600"/>
# </div>

# %% [markdown]
# <div>
# <img src="attachment:stats.png" width="600"/>
# </div>

# %% [markdown]
# ##### After these informations let's take a look at our data

# %% [markdown]
# ## 2. Common descriptive statistical measures

# %% [markdown]
# ### Measures of Central Tendency: mean, median, mode

# %% [markdown]
# **Measures of central tendency are concerned with the question what a typical value of the variable is**
#
#
# - **Mean**: an average value, sum of all values divided by the number of values
#
# - **Mode**: the value appearing most fequently in a dataset
#
# - **Median**: The median is the value in the middle of a data set, meaning that 50% of data points have a value smaller or equal to the median and 50% of data points have a value higher or equal to the median
#
#
# **Note:** the median is less prone to outliers than mean because it doesn't care about outliers, just finds the middle value
#
# * Median < Mean - outliers with large values
#
# * Median > Mean - outliers with small values

# %%
# you can sum elements in a list
numbers = [1, 1, 15, 4, 27, 35, 15]
sum(numbers)

# %%
max(numbers)

# %%
min(numbers)

# %%
pip install numpy

# %%
# Import the libraries
import numpy as np
import statistics

# %% [markdown]
# ### Using statistics

# %%
numbers

# %%
statistics.median(numbers)

# %%
statistics.mean(numbers)

# %%
statistics.mode(numbers)

# %%
b=[15, 15, 1, 4, 27, 35, 1]

# %%
statistics.mode(b)

# %% [markdown]
# ### Using Numpy

# %%
#If you want to do it with pandas
np.mean(numbers)

# %%
np.median(numbers)

# %%
np.mode(numbers)

# %%
mixed= [51,89,100, "b", "b", "d", 8.0, 1200]

# %%
statistics.mean(mixed)

# %%
statistics.mode(mixed)

# %%
statistics.median(mixed)

# %%
mixed2= [51,100,100, "b", "b", "d", 8.0, 1200]
statistics.mode(mixed2)

# %%
mixed3= [51,100, "b", "b", "d", 8.0, 8.0]
statistics.mode(mixed3)

# %%
letters= ["k","k", "b", "b", "d", "e"]
statistics.mode(letters)

# %%
letters= ["k","k", "b", "b", "d", "e"]
statistics.median(letters)

# %%
letters= ["k","k", "b", "b", "d", "e"]
statistics.mean(letters)
